# %%
import pandas as pd
import requests

# %%
response = requests.get(https://api.themoviedb.org/3/movie/top_rated?api_key=<<api_key>>&language=en-US&page=1)   # inside the get hit the API url

# %%
df = pd.DataFrame(response.json()['result']).head([['','','']])   #column name you need the dataset.

# %%
df.head()

# %%
df = pd.DataFrame()

# %%
df

# %%
for i in range(n)  # No. of rows on thw data
    response = requests.get(https://api.themoviedb.org/3/movie/top_rated?api_key=<<api_key>>&language=en-US&page=1)   # inside the get hit the API url
