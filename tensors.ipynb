# %%
import numpy as np

# %% [markdown]
# 0D

# %% [raw]
# scalar

# %%
a = np.array(6)

# %%
a
# Out:
# array(6)

# %%
a.ndim
# Out:
# 0

# %% [markdown]
# 1D

# %% [raw]
# this is also called VECTOR but for the vector its dimension is 5D

# %%
arr = np.array([1,2,3,4,5])

# %%
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr.ndim
# Out:
# 1

# %% [markdown]
# 2D

# %% [raw]
# matrix

# %%
mat = np.array([[1,4,6],[4,6,2],[8,9,5]])

# %%
mat
# Out:
# array([[1, 4, 6],
#        [4, 6, 2],
#        [8, 9, 5]])

# %%
mat.ndim
# Out:
# 2
